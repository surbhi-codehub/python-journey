# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day017python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Less Than Operator (<)

# %%
#1 Create two number variables.
num1 = 67
num2 = 87

# %%
#2 Check if the first number is less than the second using the < operator.
num1 = 56
num2 = 78

print(num1 < num2)
# Out:
# True

# %%
#3 Print the result.
num1 = 67
num2 = 78
print(num1 < num2)
# Out:
# True

# %%
#4 Try different pairs of number.
a = 78
b = 56
print(a <b)

a = 98
b = 100
print(a < b)
# Out:
# False
# True

# %%
#5 Observer when the ouput becomes True.
a = 5
b = 7
print(a < b)
# Out:
# True

# %%
#6 Obeserve when the output becomes False.
x = 56
y = 42
print(x < y)
# Out:
# False

# %%
#7 Check if the  first number is greater than the second using the > operator.
x = 84
y = 23
print(x > y)
# Out:
# True
