# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day024python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: if...else Statement

# %%
#1 Create a number varible.
num = 14
print(num)
# Out:
# 14

# %%
#2 Write an if...else statment with one simple conditon.
num = 97

if num > 90:
  print ("NUmber is greater than 5")
else:
    print("Number is 5 or less")
# Out:
# NUmber is greater than 5

# %%
#3 Print one message when the conditonis True.
num = 8

if num > 5:
  print("Condtion is True")
# Out:
# Condtion is True

# %%
#4 Print a different message when the condtion is False.
num = 9

if num > 10:
  print("Condtion is True")
else:
  print("Condtion is False")
# Out:
# Condtion is False

# %%
#5 Change the varible value and observe both outputs.

# First Output
num = 10

if num > 5:
  print("Greater than 5")
else:
  print("5 or less")

# Second Output
num = 2

if num > 5:
  print("Greater than 5")
else:
  print("5 or less")
# Out:
# Greater than 5
# 5 or less

# %%
#6 Try another simple condition using a different number.
age = 18

if age >= 18:
  print("You are eligible to vote.")
else:
  print("You are not eligible to vote.")
# Out:
# You are eligible to vote.

# %%
#7 Write an if statement with one simple condition.
marks = 75

if  marks >= 45:
   print("pass")
# Out:
# pass
