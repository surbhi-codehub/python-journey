# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day058python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Today's Topic: Common string Methods: strip().

# %%
#1.
text = "  Hello Python   "

# %%
#2.
cleaned_text = text.strip()

# %%
#3
print("original string:", text)
# Out:
# original string:   Hello Python

# %%
#4
print("Cleaned string:", cleaned_text)
# Out:
# Cleaned string: Hello Python

# %%
#5.
sentence = "   Python is easy to learn   "
clean_sentence = sentence.strip()


print("Original:", sentence)
print("Cleaned:", clean_sentence)
# Out:
# Original:    Python is easy to learn
# Cleaned: Python is easy to learn

# %%
#6
text = "  Hello python  "

print("Before strip:", text)
print("After strip:", text.strip())
# Out:
# Before strip:   Hello python
# After strip: Hello python

# %%
#7
text = "hello python"

print(text.upper())
# Out:
# HELLO PYTHON
