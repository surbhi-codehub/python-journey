# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day12python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
a = 5
b = 8

# %%
#2
a = 5
b = 3

power = a ** b
print("Power =", power)
# Out:
# Power = 125

# %%
#3
num = 6
square = num ** 2
print("Square =", square)
# Out:
# Square = 36

# %%
#4
num = 4
cube = num ** 3
print("Cube =", cube)
# Out:
# Cube = 64

# %%
#5
a = 2
b = 5
print(a ** b)
print(b ** a)
# Out:
# 32
# 25

# %%
#6
a = 5
b = 2

print("Base Number =", a)
print("Exponent =", b)
print("Result =", a ** b)
# Out:
# Base Number = 5
# Exponent = 2
# Result = 25

# %%
#7
a = 45
b = 6

remainder = a / b
print("Remainder =", remainder)
# Out:
# Remainder = 7.5
