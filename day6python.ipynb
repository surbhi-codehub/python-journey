# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day6python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Surbhi"

# %%
college = "Ranchi University"

# %%
print(name)
print(college)
# Out:
# Surbhi
# Ranchi University

# %%
favorite_food ="pani puri"

# %%
print(favorite_food)
# Out:
# pani puri

# %%
dream_job = "Data Engineer"

# %%
age = 20
print(age)
# Out:
# 20
