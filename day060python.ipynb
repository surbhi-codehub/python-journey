# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day060python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Common String Methods: final()

# %%
#1.
sentence = "I am learning python every day"
print(sentence)
# Out:
# I am learning python every day

# %%
#2.
sentence = "I am learing python every day."

position = sentence.find("python")
print(position)
# Out:
# 13

# %%
#3.
sentence = "I am learning python every day."

position = sentence.find ("learning")
print(position)
# Out:
# 5

# %%
#4.
sentence = "I am learning python every day."

position = sentence.find("every")
print(position)
# Out:
# 21

# %%
#5.
sentence = "I am learing python every day."

position = sentence.find("java")
print(position)
# Out:
# -1

# %%
#6.
sentece = "Python is every to learing."

position = sentence.find("easy")

# %%
#7.
sentence = "I am learning Python every day."

new_sentence = sentence.replace("Python", "Java")
print(new_sentence)
# Out:
# I am learning Java every day.
