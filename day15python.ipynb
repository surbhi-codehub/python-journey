# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day15python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Comparison Operator(!=)

# %%
#1 Create two number varibles.
num1 = 10
num2 = 20

# %%
#2 Check if both numbers are not equal using the != operator.
num1 = 10
num2 = 23

print(num1 != num2)
# Out:
# True

# %%
#3 print the result.
num1 = 10
num2 = 20

result = num1 != num2
print(result)
# Out:
# True

# %%
#4 Try two equal numbers and observe the the output.
num1 = 15
num2 = 15

print(num1 != num2)
# Out:
# False

# %%
#5 Try two different numbers and observe the output.
num1 = 12
num2 = 45

print(num1 != num2)
# Out:
# True

# %%
#6 Use different values and compare the results.
print(30 != 30)

print(30 != 40)

print(50 != 100)
# Out:
# False
# True
# True

# %%
#7 Check if two numbers are equal using the == operator.
num1 = 589
num2 = 589

print(num1 == num2)
# Out:
# True
