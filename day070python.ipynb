# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day70python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Reverse a String for Loop

# %%
#1.
text = "Python"

# %%
#2.
reversed_text = ""

# %%
#3.
for char in reversed(text):
    reversed_text += char

# %%
#4.
reversed_text += char

# %%
#5.
print("Original string:", text)
# Out:
# Original string: Python

# %%
#6.
text = "Python"
reversed_text = ""

for char in reversed(text):
  reversed_text += char

print("Orignal string:", text)
print("Reversed string:", reversed_text)
# Out:
# Orignal string: Python
# Reversed string: nohtyP

# %%
#7.
text = "Python"
vowels = "aeiouAEIOU"
count = 0

for char in text:
  if char.isalpha() and char not in vowels:
    count += 1

print("Number of constants:", count)
# Out:
# Number of constants: 5
