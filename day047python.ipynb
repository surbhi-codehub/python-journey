# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day047python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: pass Statement

# %%
#1 Write a simple if statment
age = 20

if age >=18:
  print("You are eligible to vote")
# Out:
# You are eligible to vote

# %%
#2 Use the pass statement inside the if block.
age = 20

if age >= 18:
  pass

# %%
#3 Run the program and observe the output
number = 10

if number > 5:
  pass

print("Program completed")
# Out:
# Program completed

# %%
#4 Replace pass with a print statment and compare the result.
number = 10

if number > 5:
  print("Number is greater than 5")
# Out:
# Number is greater than 5

# %%
#5 Try using inside a for loop.
for i in range(1, 6):
   if i == 3:
       pass
   print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#6 Try using pass inside a while loop.
i = 1

while i <= 5:
    if i == 3:
      pass
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#7 Write a simple loop using the continue statment.
for i in range(1, 6):
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
