# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day016python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Greater Than Operator(>)

# %%
#1 Create two number varibles.
num1 = 589
num2 = 345

# %%
#2 Check if first number is grater than the second using the > operator.
num1 = 789
num2 = 456
print(num1 > num2)
# Out:
# True

# %%
#3 Print the result.
num1 = 764
num2 = 987
print(num1 > num2)
# Out:
# False

# %%
#4 Try different pairs of numbers.
# pair 1
num1 = 677
num2 = 987
print(num1 > num2)

# pair 2
num1 = 999
num2 = 888
print(num1 > num2)

# pair 3
num1 = 464
num2 = 123
print(num1 > num2)
# Out:
# False
# True
# True

# %%
#5 Observe when the ouput becomes True.
a = 67
b = 56
print(a > b)
# Out:
# True

# %%
#6 Observe when the output becomes False.
a = 45
b = 123
print(a > b)
# Out:
# False

# %%
#7 Check if two numbers are not equal using the != operator.
a = 56
b = 78
print(a != b)
# Out:
# True
