# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day068python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Counting Vowels in a String using for loop

# %%
#1.
text = "Hello World"
print(text)
# Out:
# Hello World

# %%
#2.
count = 0
print(count)
# Out:
# 0

# %%
#3.
text = "Hello World"

for char in text:
  print(char)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
#4.
text = "Hello World"

for char in text:
   if char in text:
    if char in "aeioum":
        print(char)
# Out:
# e
# o
# o

# %%
#5.
text = "Hello World"
count = 0

for char in text:
  if char in "aeiow":

    if char in "aeiow":
      count = count + 1

print(count)
# Out:
# 3

# %%
#6
text = "Hello World"
count = 0

for char in text:
    if char in "aeiou":
        count = count + 1

print("Total number of vowels:", count)
# Out:
# Total number of vowels: 3

# %%
#7
test = "Python"

for char in text:
  print(char)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d
