# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day055python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: String Concatenation.

# %%
#1.
first_name = "Surbhi"
last_name = "kumari"

print(first_name)
print(last_name)
# Out:
# Surbhi
# kumari

# %%
#2.
first_name = "Surbhi"
last_name = "Kumari"

full_name = first_name + last_name

print(full_name)
# Out:
# SurbhiKumari

# %%
#4.
first = "I"
second = "love"
third = "python"

sentence = first + second + third

print(sentence)
# Out:
# Ilovepython

# %%
#5.

first = "I"
second = "Love"
third = "Python"

sentence = first  + " " + second + " " + third
print(sentence)
# Out:
# I Love Python

# %%
#6.

word1 = "Python"
word2 = "is"
word3 = "very"
word4 = "easy"

sentence = word1 + " " + word2 + " " + word3 + " " + word4
print(sentence)
# Out:
# Python is very easy

# %%
#7.
text = "Python"

length = len(text)

print(length)
# Out:
# 6
