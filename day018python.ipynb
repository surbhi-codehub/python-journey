# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day018python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Grater Than or Equal To Operator(>=)

# %%
#1 Create to number variables.
num1 = 45
num2 =78

# %%
#2 Check if the first number is greater than or equal to the second using the >= operator.
num1 = 56
num2 = 23
print(num1 >= num2)
# Out:
# True

# %%
#3 Print the result.
num1 = 54
num2 = 67
result = num1 >= num2
print(result)
# Out:
# False

# %%
#4 Try two equla numbers and observe the output.
a = 45
b = 45
print(a >= b)
# Out:
# True

# %%
#5 Try different pairs of numbers.
a = 56
b = 78
print(a >= b)
# Out:
# False

# %%
#6 Observe when the output becomes True and False.
a = 5
b = 6
print(a >= b)


x = 78
y = 45
print(x >= y)
# Out:
# False
# True

# %%
#7 Check if the first number is less than the second using the < operator.
a = 23
b = 56
print(a < b)
# Out:
# True
