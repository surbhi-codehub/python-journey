# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day051python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Introduction to string.

# %%
#1 Create astring varible to store your name.
name = "Surbhi"
print(name)
# Out:
# Surbhi

# %%
#2 Create another string variable to store your favirte color.
color = "pink"
print(color)
# Out:
# pink

# %%
#3 Change the value of one string and print it again.
name = "Surbhi"
print(name)


name = "Twinkle"

print("My name is " + name)
# Out:
# Surbhi
# My name is Twinkle

# %%
#4 Change the value of one string and print it again.
name = "Surbhi"
print(name)

name = "Anchal"
print(name)
# Out:
# Surbhi
# Anchal

# %%
#5 Create a sntence using a string varible.
name = "Surbhi"

print("my name is " + name)
# Out:
# my name is Surbhi

# %%
#6 Print three different string varibles together.
name = "Anu"
colour = "pink"
city = "Ranchi"

print(name, colour, city)
# Out:
# Anu pink Ranchi

# %%
#7 print aright tringle pattern using nested for loops.
for i in range(1, 6):
  for j in range(i):
    print("*", end=" ")
  print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
