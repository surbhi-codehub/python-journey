# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
is_student = True

# %%
is_raning = False

# %%
print(is_student)
print(is_raning)
# Out:
# True
# False

# %%
likes_python = True

# %%
print(is_student)
print(is_raning)
print(likes_python)
# Out:
# True
# False
# True

# %%
has_pet = False
print(has_pet)
# Out:
# False

# %%
height = 5.2
print(height)
# Out:
# 5.2
