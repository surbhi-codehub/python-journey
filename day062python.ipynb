# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day062python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: startwith() String Method.

# %%
#1.
sentence = "Python is very easy to learn."
print(sentence)
# Out:
# Python is very easy to learn.

# %%
#2.
sentence = "Python is very easy to learn."

result = sentence.startswith("Python")
print(result)
# Out:
# True

# %%
#3.
sentence = "Python is very easy to learn."

print(sentence.startswith("Python"))
# Out:
# True

# %%
#4.
sentence = "Python is very easy to learn."

print(sentence.startswith("Java"))
# Out:
# False

# %%
#5.
sentence = "Java is a programming language."

print(sentence.startswith("Java"))
# Out:
# True

# %%
#6.
sentence1 = "Python is easy."
sentence2 = "Java is powerful."

print(sentence1.startswith("Python"))
print(sentence2.startswith("Python"))
# Out:
# True
# False

# %%
#7.
sentence = "Python is easy. Python is powerful."

print(sentence.count("Python"))
# Out:
# 2
