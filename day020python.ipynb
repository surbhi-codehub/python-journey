# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day020python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Logical AND Operator(and)

# %%
#1 Create two comparison exprisons.
a = 78
b = 45
print(a < b)
print(a > b)
# Out:
# False
# True

# %%
#2 Use the and operator to combine both expressions.
a = 10
b = 20
result = (a < b) and (b > 15)
print(result)
# Out:
# True

# %%
#3 print the result.
a = 70
b = 80
print((a < b) and (b > 75))
# Out:
# True

# %%
#4 Change one value and observe the output.
a = 90
b = 80
print((a < b) and (b > 75))
# Out:
# False

# %%
#5 Make both expression True and check the result.
a = 5
b = 25
print((a <b) and (b > 10))
# Out:
# True

# %%
#6 Make one expression False and observe the output.
a = 15
b = 10
print((a < b) and (b > 5))
# Out:
# False

# %%
#7 Check if one number is less than or equal to another using the < = operator.
a = 100
b = 100
print(a <= b)
# Out:
# True
