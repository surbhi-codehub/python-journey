# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day056python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: String Repetition using * Operator

# %%
#1.
name = "Python"
print(name)
# Out:
# Python

# %%
#2.
name = "python"
print(name * 3)
# Out:
# pythonpythonpython

# %%
#3
word = "Hello"
print(word * 5)
# Out:
# HelloHelloHelloHelloHello

# %%
#4
word = "Hi"

print(word * 2)
print(word * 4)
print(word * 6)
# Out:
# HiHi
# HiHiHiHi
# HiHiHiHiHiHi

# %%
#5
star = "*"
print(star * 5)
# Out:
# *****

# %%
#6
word = "Python"

print(word * 1)
print(word * 2)
print(word * 3)
print(word * 4)
# Out:
# Python
# PythonPython
# PythonPythonPython
# PythonPythonPythonPython

# %%
#7
first = "Hello"
second = "Python"

print(first + " " + second)
# Out:
# Hello Python
