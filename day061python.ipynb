# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day061python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Common String Methods: count()

# %%
#1.
sentence = "Python is easy and Python is fun."

# %%
#2.
sentence = "Python is easy and Python is fun."

result = sentence.count("P")
print(result)
# Out:
# 2

# %%
#3.
sentence = "Python is easy and Python is fun."


count_p = sentence.count("P")
print("P appears", count_p, "times")
# Out:
# P appears 2 times

# %%
#4.
sentence = "Python is easy and Python is fun."

count_python = sentence.count("Python")
print("Python appears", count_python, "times")
# Out:
# Python appears 2 times

# %%
#5.
sentence = "I love Python is my favorite."

print(sentence.count("Python"))
# Out:
# 1

# %%
#6.
sentence = "Python is easy and Python is fun."

print("Python:", sentence.count("Python"))
print("is:", sentence.count("is"))
print("o:", sentence.count("o"))
# Out:
# Python: 2
# is: 2
# o: 2

# %%
#7.
sentence = "Python is easy and Python is fun."

position = sentence.find("Python")
print(position)
# Out:
# 0
