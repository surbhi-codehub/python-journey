# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day023python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Introduction to if Statement

# %%
#1 Create a number varible.
number = 56

# %%
#2 Write an if statement with one simple condition.
num = 45
if num > 40:
   print("Number is greater than 5")
# Out:
# Number is greater than 5

# %%
#3 Print a message only when the condition is True.
num = 78

if num == 78:
  print("Condition is True")
# Out:
# Condition is True

# %%
#4 Change the varible value and observe the output.
num = 98

if num > 100:
  print("Number is greater than 5")

# %%
#5 Try another condition using a differnt number.
num = 45

if num > 35:
  print("Number is greater than 35")
# Out:
# Number is greater than 35

# %%
#6 Print a different message when the condition becomes True.
marks = 78

if marks  >= 50:
  print("You Passed!")
# Out:
# You Passed!

# %%
#7 Use the not operator with a comparison expression.
num = 78

if not (num > 89):
  print(("Number is not greater than 89"))
# Out:
# Number is not greater than 89
