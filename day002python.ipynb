# %%
name ="Surbhi Kumari"

# %%
age =20

# %%
name ="Surbhi Kumari"
age =20;
print (name)
print (age)
# Out:
# Surbhi Kumari
# 20

# %%
color ="Green"
print(color)
# Out:
# Green

# %%
college = "Ranchi University"
print (college)
# Out:
# Ranchi University

# %%
number =25
print(number)
# Out:
# 25

# %%
print ("Hello, Python")
# Out:
# Hello, Python
