# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day019python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Less Than or Equal To Operator(<=)

# %%
#1 Create two numbers varibles.
a = 45
b = 96

# %%
#2 Check if the first number is less than or equal to the second using the <=operator.
a = 67
b = 78
print(a <= b)
# Out:
# True

# %%
#3 Print the result.
a = 78
b = 56
result = a <= b
print(result)
# Out:
# False

# %%
#4 Try two equal numbersand observe and output.
a = 98
b = 98
print(a <= b)
# Out:
# True

# %%
#5 Try different pair of numbers.
a = 78
b = 67
print(a <= b)


num1 = 45
num2 = 98
print(num1 <= num2)
# Out:
# False
# True

# %%
#6 Observe when the output becomes True and False.
a = 78
b = 99
print(a <= b)


num1 = 77
num2 = 56
print(num1 <= num2)
# Out:
# True
# False

# %%
#7 Check if the first number is greater than or equal to the second using the >= operator.
num1 = 78
num2 = 33
print(num1 >= num2)
# Out:
# True
