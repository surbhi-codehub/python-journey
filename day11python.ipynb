# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day11python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
num1 = 45
num2 = 5

# %%
#2
num1 = 80
num2 =2

remainder = num1 /num2
print(remainder)
# Out:
# 40.0

# %%
#3
a = 68
b = 6

print(a / b)
# Out:
# 11.333333333333334

# %%
#4
number = 15

print(number / 2)
# Out:
# 7.5

# %%
#5
x = 98
y = 4

print(x / y)
# Out:
# 24.5

# %%
#6
num1 = 5674
num2 = 25

print(num1 / num2)
# Out:
# 226.96

# %%
#7
a = 50
b = 2

print(a + b)
# Out:
# 52
