# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day054python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: String Length using len()

# %%
#1.
name = "Surbhi"
print(name)
# Out:
# Surbhi

# %%
#2.
name = "Surbhi"
print(len(name))
# Out:
# 6

# %%
#3.
city = "Ranchi"
print(len(city))
# Out:
# 6

# %%
#4.
name = "Arti"
city = "patna"

if len(name) > len(city):
  print("Name is longer")
elif len(name) < len(city):
  print("city is longer")
else:
  print("Both have the same length")
# Out:
# city is longer

# %%
#5.
sentence = "I love python"
print(len(sentence))
# Out:
# 13

# %%
#6.
text = "Hello World"
print(len(text))
# Out:
# 11

# %%
#7.
text = "Python"

print(text[:3])
print(text[-3:])
# Out:
# Pyt
# hon
