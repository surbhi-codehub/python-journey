# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day053python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# topic: String Slicing

# %%
#1.
name = "Surbhi"
print(name)
# Out:
# Surbhi

# %%
#2.
name = "Surbhi"
print(name[:3])
# Out:
# Sur

# %%
#3.
name = "Twinkle"
print(name[-3:])
# Out:
# kle

# %%
#4.
name = "Surbhi"
print(name[2:5])
# Out:
# rbh

# %%
#5.
name = "Surbhi"

print(name[0:2])
print(name[2:4])
print(name[2:5])
print(name[0:6])
# Out:
# Su
# rb
# rbh
# Surbhi

# %%
#6.
name = "Surbhi"

print(name[0:3])
print(name)
# Out:
# Sur
# Surbhi

# %%
#7
name = "Surbhi"

print(name[0])
print(name[-1])
# Out:
# S
# i
