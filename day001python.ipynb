# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
print ("Surbhi Kumari")
# Out:
# Surbhi Kumari

# %%
print("I am studying BCA")
# Out:
# I am studying BCA

# %%
print ("15+25=40")
# Out:
# 15+25=40

# %%
for i in range(5):
  print("❤️")
# Out:
# ❤️
# ❤️
# ❤️
# ❤️
# ❤️

# %%
color =input ("Enter your favorite color:")
print ("your favorite color is ",color)
# Out:
# Enter your favorite color:Blue
# your favorite color is  Blue

# %%
food =input ("Enter your favorit food:")
print ("Greet choise!")
# Out:
# Enter your favorit food:Momos
# Greet choise!
