# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day069python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Counting Consonants in a String using for Loop.

# %%
#1.
text = "Hello World"

# %%
#2.
count = 0

# %%
#3.
for char in text:
  print(char)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
#4.
if char.isalpha() and char.lower() not in "aeiou":
  print(char)
# Out:
# d

# %%
#5
if char.isalpha() and char.lower() not in "aeiou":
  count += 1

# %%
#6
print("Total constants:",count)
# Out:
# Total constants: 2

# %%
#7
text = "Hello World"
count = 0

for char in text:
  if char.lower() in "aeiou":
    count += 1

print("Total vowels:", count)
# Out:
# Total vowels: 3
