# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day13python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Floor Division Operator

# %%
#1
num1 = 5
num2 = 4

# %%
#2
num1 = 20
num2 = 6

result = num1 // num2
print(result)
# Out:
# 3

# %%
#3
a = 25
b = 3

print(a // b)
# Out:
# 8

# %%
#4
a = 25
b = 4

print(a / b)
print(a // b)
# Out:
# 6.25
# 6

# %%
#5
a = 35
b = 6

print("Floor Division Result:", a // b)
# Out:
# Floor Division Result: 5

# %%
#6
a = 1000
b = 33

print(a // b)
# Out:
# 30

# %%
#7
num = 9

print(num ** 2)
# Out:
# 81
