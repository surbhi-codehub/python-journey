# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day043python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Multiplication Table using while loop.

# %%
#1. Ask the user to enter a number.
num = input("Enter a number:")
# Out:
# Enter a number:68

# %%
#2. Convert the input an integer.
num = int(input("Enter a number:"""))
# Out:
# Enter a number:788765

# %%
#3. Create a conter starting from 1.
num = int(input("Enter a number: "))
i = 1
# Out:
# Enter a number: 4

# %%
#4. Use a while loop to print the multiplication table up to 10.
num = int(input("Enter a number: "))
i = 1

while i <= 10:
    print(num * i)
    i +=1
# Out:
# Enter a number: 7
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70

# %%
#5. Increase the counter after each loop.
i += 1

# %%
#6. Test the program with two different numbers.
num = int(input("Enter a number: "))

i = 1

while i <= 10:
    print(num, "x", i, "=", num * i)
    i += 1
# Out:
# Enter a number: 6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %%
#7. Find the sum of number 1 to 10 using a while loop.
i = 1
total = 0

while i <= 10:
   total = total + i
   i += 1

print("Sum =", total)
# Out:
# Sum = 55
