# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day028python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Even or Odd Number using if...else

# %%
#1
num = input("Enter a number: ")
# Out:
# Enter a number: 678

# %%
#2
num = int(input("Enter a number:"))
# Out:
# Enter a number:456

# %%
#3
num % 2 == 0
# Out:
# True

# %%
#4
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even")
else:
  print("odd")
# Out:
# Enter a number: 67
# odd

# %%
#5
num = int(input("Enter a number: "))

if num % 2 == 0:
  print("Even")
else:
  print("odd")
# Out:
# Enter a number: 12
# Even

# %%
#6
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even")
else:
    print("odd")
# Out:
# Enter a number: 55
# odd

# %%
#7
num = int(input('Enter a number: '))

if num > 0:
    print("positive Number")
# Out:
# Enter a number: 78
# positive Number
