# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day066python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: String Membership: in and not in.

# %%
#1.
sentence = "I love learning Python"

# %%
#2.
result1 = "Python" in sentence

# %%
#3.
print(result1)
# Out:
# True

# %%
#4.
result2 = "Java" not in sentence

# %%
#5.
print(result1)
print(result2)
# Out:
# True
# True

# %%
#6.
sentence = "I love learing Python"

print("Python" in sentence)
print("love" in sentence)
print("Java" in sentence)
print("Java" not in sentence)
# Out:
# True
# True
# False
# True

# %%
#7.
words = ["I", "love", "learing", "Python"]

sentence = " ".join(words)

print(sentence)
# Out:
# I love learing Python
