# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day025python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: if...elif...else Statement

# %%
#1 Create a number variable.
num = 15

# %%
#2 Write an if...elif...else statement with simple conditions.l
num = 15

if num > 20:
  print("Number is greater than 20")
elif num > 10:
  print("Number is greater than 10")
else:
  print("number is 10 or less")
# Out:
# Number is greater than 10

# %%
#3 Print a different message for each condition.
num = 8

if num > 20:
  print("The Number is very large.")
elif num> 10:
  print("The number is medium.")
else:
  print("The number is small.")
# Out:
# The number is small.

# %%
#5 Add one more elif condtion.
num = 5

if num > 20:
  print("Greater than 20")
elif num > 10:
  print("Greater than 10")
elif num > 5:
  print("Grater than 5")
else:
  print("5 or less")
# Out:
# 5 or less

# %%
#6 Try the different number and compare the ouputs.
num = 1

if num > 20:
  print("Greater than 20")
elif num > 10:
  print("Grater than 10")
elif num > 5:
  print("Greater than 5")
else:
  print("5 or less")
# Out:
# 5 or less

# %%
#7 Write a simple if...else statment.
num = 12

if num > 10:
  print("number is greater than 10")
else :
  print("Number is 10 or less")
# Out:
# number is greater than 10
