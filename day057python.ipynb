# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day057python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Common String Methods: upper() and lower ()

# %%
#1.
name = "Surbhi"
print(name)
# Out:
# Surbhi

# %%
#2.
name = "Surbhi"

print(name.upper())
# Out:
# SURBHI

# %%
#3.
name = "Surbhi"
print(name.lower())
# Out:
# surbhi

# %%
#4.
city = "Ranchi"

print(city.upper())
print(city.lower())
# Out:
# RANCHI
# ranchi

# %%
#5.
name = "Surbhi"

print(name == name.upper())
print(name == name.lower())
# Out:
# False
# False

# %%
#6.
sentence = "python is easy to learn"

print(sentence.upper())
print(sentence.lower())
# Out:
# PYTHON IS EASY TO LEARN
# python is easy to learn

# %%
#7.
text = "python"

print(text * 3)
# Out:
# pythonpythonpython
