# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day14python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Topic: Comparison Operator(==)

# %%
#1 Create two number varible.
a = 10
b = 6

# %%
#2 Check if both number are equal using the == operator
a = 9
b = 9

print(a == b)
# Out:
# True

# %%
#3 Print the result.
a = 25
b = 34

result =(a == b)
print(result)
# Out:
# False

# %%
#5 Try different values nand observe when the result charges.
a = 8
b = 8

print(a == b)


a = 7
b = 6
print(a == b)
# Out:
# True
# False

# %%
#6 Compare two equal numbers.
x = 100
y = 100

print(x == y)
# Out:
# True

# %%
#7 Compare two different numbers.
x = 89
y = 78

print(x == y)
# Out:
# False
