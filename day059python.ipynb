# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day059python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Common String Method: replace()

# %%
#1.
sentence = "I like python programming."

# %%
#2.
updated_sentence = sentence.replace("Python", "Java")

# %%
#3.
print("Original string:", sentence)
# Out:
# Original string: I like python programming.

# %%
#4.
print("Updated string:", updated_sentence)
# Out:
# Updated string: I like python programming.

# %%
#5.
new_sentence = sentence.replace("like", "love")
print("New string:", new_sentence)
# Out:
# New string: I love python programming.

# %%
#6.
print("Original:", sentence)
print("Updated:", updated_sentence)
# Out:
# Original: I like python programming.
# Updated: I like python programming.

# %%
#7.
text = "   Hello, World   "

clean_text = text.strip()

print("Original:", text)
print("After strip:", clean_text)
# Out:
# Original:    Hello, World
# After strip: Hello, World
