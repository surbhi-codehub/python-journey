# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day052python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: String Indexing

# %%
#1
name = "Surbhi"
print(name)
# Out:
# Surbhi

# %%
#2
name = "Surbhi"
print(name[0])
# Out:
# S

# %%
#3
name = "Surbhi"

print(name[-1])
# Out:
# i

# %%
#4
color = "pink"

print(color[1])
# Out:
# i

# %%
#5 Try accessing different position in the string.
name = "Surbhi"

print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
print(name[5])
# Out:
# S
# u
# r
# b
# h
# i

# %%
#6 Observe how Character poistion start from 0.
name = "Surbhi"

print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
print(name[5])
# Out:
# S
# u
# r
# b
# h
# i

# %%
#7
name = "Surbhi"
color = "Pink"
city = "Ranchi"

print(name)
print(color)
print(city)
# Out:
# Surbhi
# Pink
# Ranchi
