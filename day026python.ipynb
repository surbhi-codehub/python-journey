# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day026python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Nested if Statment.

# %%
#1 Create anumber varible.
num = 7

# %%
#2 Write an if statement.
num = 15

if num > 10:
  print("Number is greater than 10")
# Out:
# Number is greater than 10

# %%
#3 Inside the first if block,write another if statement.
num = 6

if num > 10:
   if num < 20:
      print("NUmber is between 10 and 20")

# %%
#4 Print a message when both condition are True.
num = 15

if num > 10:
    if num < 30:
        print("Both condition are True")
# Out:
# Both condition are True

# %%
#5 Change the varible value and observe the output.
num = 25

if num > 10:
  if num < 40:
    print("Both conditon are True")
# Out:
# Both conditon are True

# %%
#6 Try different values and see which messages are printed.
num = 8

if num > 20:
   if num < 40:
      print("NUmber is between 20 and 40")
else:
     print("Number is 10 or less")
# Out:
# Number is 10 or less

# %%
#7 Write a simple if...elif...else statment
num = 20

if num < 10:
  print("Small NUmber")
elif num < 20:
  print("Medium Number")
else:
  print("Large Number")
# Out:
# Large Number
