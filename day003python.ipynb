# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a string varivble to store your favorite food
favorite_food = "pani puri"
print(favorite_food)
# Out:
# pani puri

# %%
# Create an integer varible to store your luncy number.
lucky_number = 7
print(lucky_number)
# Out:
# 7

# %%
# Create a string varible of your city name.
city = "Ranchi"
print(city)
# Out:
# Ranchi

# %%
# Print both varibles.
favorite_food = "pani puri"
lucky_number = 7
print(favorite_food)
print(lucky_number)
# Out:
# pani puri
# 7

# %%
# CREate string an interge varible for your birth year.
birth_year = 2005
print(birth_year)
# Out:
# 2005

# %%
# Print all four varible together.
favorite_food = "pani puri"
lucky_number = 7
city = "Ranchi"
birth_year

print(favorite_food)
print(lucky_number)
print(city)
print(birth_year)
# Out:
# pani puri
# 7
# Ranchi
# 2005

# %%
# (Revision): Create a varible for your name again and print it.
name = "Surbhi"
print(name)
# Out:
# Surbhi
