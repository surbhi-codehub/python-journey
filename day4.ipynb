# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Store your height using a decimal number
height = 5

# %%
# Store the price of a chocolate using a decimal number
chocolate_price = 25.50

# %%
# print both varibles
print("Height:",height)
# Out:
# Height: 5

# %%
#Store your exam percentage using values
exam_percentage = 67.45

# %%
# Print all three decimal values
print("Height:",height)
print("Chocolate_price:",chocolate_price)
print("exame_percentage:",chocolate_price)
# Out:
# Height: 5
# Chocolate_price: 25.5
# exame_percentage: 25.5

# %%
# Store your favorite drink's price
drink_price = 50.50
print("Favorite Drink price:", drink_price)
# Out:
# Favorite Drink price: 50.5

# %%
# (Revision):Store your name print it
name = "Surbhi"
print("Name:",name)
# Out:
# Name: Surbhi
