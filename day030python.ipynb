# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day030python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Mini Practice - Number Checker

# %%
#1 Ask the user enter your number.
num =int(input("Enter a number: "))
# Out:
# Enter a number: 67

# %%
#2 Convert the input into an integer.
num =int(input("Enter a number: "))
# Out:
# Enter a number: 89

# %%
#3 Check the weather the number is positive negative or zero.
num=int(input("Enter a number: "))

if num > 0:
  print("The number is positive.")
elif num < 0:
  print("The number is negative.")
else:
  print("The number is Zero.")
# Out:
# Enter a number: -67
# The number is negative.

# %%
#4 If the number is positive , check weater it is even or odd.
num = int(input("Enter a number: "))

if num > 0:
  if num % 2 == 0:
    print("The number is positive and even.")
  else:
      print("The number is positive and odd.")
elif num < 0:
  print("The number is Negative.")
else:
  print("The number is Zero.")
# Out:
# Enter a number: 0
# The number is Zero.

# %%
#5 Print asuitable message for every result.
num = int(input("Enter a number: "))

if num > 0:
  if num % 2 == 0:
    print("The number is Positive and Even.")
  else:
    print("The number is Positve and Odd.")
elif num < 0:
  print("The number is Negative.")
else:
  print("The number is Zero")
# Out:
# Enter a number: -98
# The number is Negative.

# %%
#6 Test your program using at least five different numbers.
num = int(input("Enter a number: "))

if num > 0:
  if num % 2 == 0:
    print("The number is Positive and Odd.")
  else:
    print("The number is Positive and Even")
elif num < 0:
  print("The number is Negative.")
else:
  print("The number is Zero.")
# Out:
# Enter a number: 77
# The number is Positive and Even

# %%
#7 Write a program using if...elif ...else.
num = int(input("Enter number: "))

if num > 0:
  if num % 2 == 0:
    print("The number is Positive and Even")
  else:
    print("The number is Positive and Odd.")
elif num < 0:
    print("The number is Negative.")
else:
    print("The number is Zero")
# Out:
# Enter number: 67876
# The number is Positive and Even
