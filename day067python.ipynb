# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day067python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Iterating Through a String uing for Loop

# %%
#1.
name = "Surbhi"

# %%
#2.
name = "Surbhi"

for char in name:
  print(char)
# Out:
# S
# u
# r
# b
# h
# i

# %%
#3.
name = "Kumari"

for char in name:
  print(char)
# Out:
# K
# u
# m
# a
# r
# i

# %%
#4.
name = "Surbhi"
count = 0

for char in name:
   print(char)
   count = count + 1

print("Total character:", count)
# Out:
# S
# u
# r
# b
# h
# i
# Total character: 6

# %%
#5.
sentence = "I love Python"

for char in sentence:
  print(char)
# Out:
# I
#
# l
# o
# v
# e
#
# P
# y
# t
# h
# o
# n

# %%
#6.
word = "Python"

for char in word:
  print("Current character:", char)
# Out:
# Current character: P
# Current character: y
# Current character: t
# Current character: h
# Current character: o
# Current character: n

# %%
#7.
sentence = "I love Python"

if "Python" in sentence:
  print("Python is exists in the string")
else:
  print("Python does not exist")
# Out:
# Python is exists in the string
