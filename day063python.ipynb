# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day063python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Today's Topic: Common String Method: endswith()

# %%
#1.
sentence = "I love learning Python"

# %%
#2.
sentence = "I love learning Python"

result = sentence.endswith("Python")

# %%
#3.
sentence = "I love learing Python"

result = sentence.endswith("Python")

print(result)
# Out:
# True

# %%
#4.
sentence = "I love learing Python"

result = sentence.endswith("Java")

print(result)
# Out:
# False

# %%
#5.
message = "Python is easy"

result = message.endswith("esay")

print(result)
# Out:
# False

# %%
#6.
string1 = "I love Python"
string2 = "I love Java"

print(string1.endswith("Python"))
print(string2.endswith("Python"))
# Out:
# True
# False

# %%
#7.
sentence = "Python is easy"
result = sentence.startswith("Python")
print(result)
# Out:
# True
