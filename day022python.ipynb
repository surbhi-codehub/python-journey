# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day022python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Logical NOT Operator(not)

# %%
#1 Create a comparison expession.
a = 10
b = 5
print(a > b)
# Out:
# True

# %%
#2 Use the not operator with  the comparison expression.
a = 10
b = 5
print(not(a >b))
# Out:
# False

# %%
#3 Print the result.
a = 70
b = 60
result = not(a > b)
print(result)
# Out:
# False

# %%
#4 Change the values and observe how the result changes.
a = 78
b = 90
print(not(a > b))
# Out:
# True

# %%
#5 Try an expression that gives True.
a = 89
b = 99
print(not (89 > 99))
# Out:
# True

# %%
#6 Try an expression that gives False.
a = 56
b = 44
print(not (56 > 10))
# Out:
# False

# %%
#7 Use the or opeator with two comparison expressions.
a = 10
b = 90
print((a > b) or (a < b))
# Out:
# True
