# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day7python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first_name = "Surbhi"
last_name = "kumari"
print(first_name)
print(last_name)
# Out:
# Surbhi
# kumari

# %%
first_name = "Surbhi"
last_name = "Kumari"
full_name = first_name +" " + last_name

# %%
first_name = "Surbhi"
last_name = "kumari"
full_name = first_name + " " + last_name

print(full_name)
# Out:
# Surbhi kumari

# %%
city = "Ranchi"
state = "Jharkhand"
print(city)
print(state)
# Out:
# Ranchi
# Jharkhand

# %%
city = "Ranchi"
state = "Jharkhand"

location = city + ", " + state

print(location)
# Out:
# Ranchi, Jharkhand

# %%
greeting = " Hello"
name = "Surbhi"

message = greeting + " " + name
print(message)
# Out:
#  Hello Surbhi

# %%
is_student = True

print(is_student)
# Out:
# True
