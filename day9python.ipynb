# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day9python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 Ask the user to enter their age.
age = input("Enter your age:")
# Out:
# Enter your age:21

# %%
#2 Store the entered age in a varible .
age = input("Enter your age:")
# Out:
# Enter your age:21

# %%
#3 Convert the age into integer.
age = int(age)

# %%
#4 Print the converted age.
print(age)
# Out:
# 21

# %%
#5 Create a number variable and convert it into a string.
number = 100
number = str(number)

# %%
#6 Print the convert sting.
print(number)
# Out:
# 100

# %%
#7 Ask the user to enter their favorite color and print it.
color = input("Enter your favorite color:")
print("Your favorite color is;",color)
# Out:
# Enter your favorite color:Yellow
# Your favorite color is; Yellow
