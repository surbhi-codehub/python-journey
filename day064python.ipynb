# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day064python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Common String Method: split()

# %%
#1.
sentence = "Python is very easy"

# %%
#2.
sentence = "Python is very easy"
words = sentence.split()

# %%
#3
sentence = "Python is very easy"
words = sentence.split()

print(words)
# Out:
# ['Python', 'is', 'very', 'easy']

# %%
#4
sentence = "Python is very easy"
words = sentence.split()

print(len(words))
# Out:
# 4

# %%
#5.
sentence = "I am learning Python"
words = sentence.split()

print(words)
# Out:
# ['I', 'am', 'learning', 'Python']

# %%
#6.
sentence = "Python is easy"
words = sentence.split()

print(type(words))
# Out:
# <class 'list'>

# %%
#7.
sentence = "I am learnig Python"

print(sentence.endswith("Python"))
# Out:
# True
