# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day10python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 Create two number.
num1 = 10
num2 = 5

# %%
#2 Find their addition and print the result.
num1 = 10
num2 = 5
addition = num1 + num2
print("Addition =", addition)
# Out:
# Addition= 15

# %%
#3 Find their subtraction and print the result.
num1 = 67
num2 = 45
subtraction = num1 - num2
print("Subtraction =", subtraction)
# Out:
# Subtraction = 22

# %%
#4 Find their multiplication and print the result.
num1 = 34
num2 = 23
multiplication = num1 * num2
print("Multiplication =", multiplication)
# Out:
# Multiplication = 782

# %%
#5 Find the division and print the result.
num1 = 45
num2 = 5
division = num1 / num2
print("Division =",division)
# Out:
# Division = 9.0

# %%
#6 Try using different number and observed the output.
num1 = 45
num2 = 5
print("Addition =", num1 + num2)
print("Subtraction =", num1 - num2)
print("Multiplication =", num1 * num2)
print("Division =", num1 /num2 )
# Out:
# Addition = 50
# Subtraction = 40
# Multiplication = 225
# Division = 9.0

# %%
#7 Ask the user to enter their age,convert it into an integer, and print it.
age = int(input("Enter your age: "))
print("Your age is:", age)
# Out:
# Enter your age: 20
# Your age is: 20
