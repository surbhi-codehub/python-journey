# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/Copy_of_day029python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Positive, Negative or Zero using if...elif...else.

# %%
#1 Ask the user to enter a number.
num = input("Enter anumber: ")
# Out:
# Enter anumber: 98

# %%
#2 Convert the input an integer.
num = int(num)

# %%
#3 Use an if statment to check if the number is greater than Zero.
if num > 0:
  print("The number is positive.")
# Out:
# The number is positive.

# %%
#4 Use an elif statment to check if the number is equal to zero.
num =int(input("Enter a number: "))

if num > 0:
 print("The number is positive.")
elif num == 0:
   print("The number is Zero.")
else:
  print("The number is Negative.")
# Out:
# Enter a number: 0
# The number is Zero.

# %%
#5 Use an else statment for negative numbers.
num = int(input("Enter a number: "))

if num> 0:
  print("The number is positive.")
elif num == 0:
  print("The number is Zero.")
else:
  print("The number is Negative.")
# Out:
# Enter a number: -5
# The number is Negative.

# %%
#6 Print an apportiate message for each case.
num = int(input("En:ter a number: "))

if num > 0:
  print("The number is positive.")
elif num == 0:
  print("The number is Zero ")
else:
   print("The number is Negative.")
# Out:
# En:ter a number: 2
# The number is positive.

# %%
#7 Write a program to check wheater a number is even or odd.
num = int(input("Enter a number: "))
if num % 2 == 0:
  print("The number is Even .")
else:
    print("The  number is odd")
# Out:
# Enter a number: 56
# The number is Even .
