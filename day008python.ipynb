# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/python-journey/blob/main/day8python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 Ask the user enter your name.
input("Enter your name:")
# Out:
# Enter your name:Surbhi Kumari
# 'Surbhi Kumari'

# %%
#2 Store the entered name in a varible.
name = input("Enter your name:")
# Out:
# Enter your name:Surbhi Kumari

# %%
#3 Print the name.
name = input("Enter your name:")
print(name)
# Out:
# Enter your name:Surbhi Kumari
# Surbhi Kumari

# %%
#4 Ask the user to enter their favorit color.
input("Enter your favorite color:")
# Out:
# Enter your favorite color:blue
# 'blue'

# %%
#5 Store the color in a varible.
color = input("Enter your favorite color:")
# Out:
# Enter your favorite color:blue

# %%
#6 Print your favorite color.
color = input("Enter your favorite color:")
print(color)
# Out:
# Enter your favorite color:blue
# blue

# %%
#7 create two string varible and join them into one sentence.
first = "Hello"
second = "Surbhi"

print(first + " " + second)
# Out:
# Hello Surbhi
